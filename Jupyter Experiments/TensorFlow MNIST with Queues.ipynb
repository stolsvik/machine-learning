# %%
# Author: Endre Stølsvik, around 2017-07-01

import tensorflow as tf
# https://github.com/tensorflow/tensorflow/blob/master/tensorflow/contrib/learn/python/learn/datasets/mnist.py
import tensorflow.examples.tutorials.mnist.input_data as input_data
from timeit import default_timer as timer

# Hyperparameters
hidden1_size = 800
hidden2_size = 800
epochs = 20   # Not explicitly used, as we count mini_batches
mini_batch_size = 128
learning_rate = 0.0001

# Load data, calculate total mini batches:
mnist = input_data.read_data_sets("tmp", one_hot=True, validation_size=0)
mini_batches_per_epoch = int(mnist.train.num_examples / mini_batch_size)
total_mini_batches = epochs * mini_batches_per_epoch

# Define Neural Network

def weight_variable(shape):
  return tf.Variable(tf.truncated_normal(shape, stddev=0.1))

def bias_variable(shape):
  return tf.Variable(tf.constant(0.1, shape=shape))

def createNeuralNet(inputs, labels):
    layer1_w = weight_variable([28*28, hidden1_size])
    layer1_b = bias_variable([hidden1_size])
    layer1 = tf.matmul(inputs, layer1_w) + layer1_b
    layer1 = tf.nn.elu(layer1)

    layer2_w = weight_variable([hidden1_size, hidden2_size])
    layer2_b = bias_variable([hidden2_size])
    layer2 = tf.matmul(layer1, layer2_w) + layer2_b
    layer2 = tf.nn.elu(layer2)

    # Layer3 == Output layer
    # Notice: Raw values; No activation/transfer function (i.e. Sigmoid, ReLU), nor dropout
    layer3_w = weight_variable([hidden2_size, 10])
    layer3_b = bias_variable([10])
    layer3 = tf.matmul(layer2, layer3_w) + layer3_b

    # Prediction = output
    prediction = layer3


    # Define Training: Loss/Cost and Optimizer
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=prediction, labels=labels))
    optimizer = tf.train.AdamOptimizer(learning_rate)
    # optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    train = optimizer.minimize(cost)

    # Define Test/Evaluate: Accuracy: Fraction right predictions
    correct_prediction = tf.equal(tf.argmax(prediction, 1), tf.argmax(labels, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

    return train, cost, accuracy

inputs = labels = train = cost = accuracy = None

# Reset default graph so that we can run again in Jupyter Notebook
tf.reset_default_graph()
# Create TensorFlow Session
s = tf.Session()

def printStats(what):
    train_cost, train_accuracy = s.run([cost, accuracy], 
                                       feed_dict={inputs: mnist.train.images, labels: mnist.train.labels})
    test_cost, test_accuracy = s.run([cost, accuracy], 
                                     feed_dict={inputs: mnist.test.images, labels: mnist.test.labels})
    print("{}\n  TRAIN cost/acc:{:.4f}/{:.4f}, TEST cost/acc:{:.4f}/{:.4f}"\
          .format(what, train_cost, train_accuracy, test_cost, test_accuracy))

print ("\nNeural network: Hidden1:{}, Hidden2:{}"\
       .format(hidden1_size, hidden2_size))
print(" Training size:{} * epochs:{} / mini_batch_size:{} = total_mini_batches:{}"\
       .format(mnist.train.num_examples, epochs, mini_batch_size, total_mini_batches))
print(" Learning rate:{}\n"\
      .format(learning_rate))

# ----------
import subprocess
import shlex
nvidia_smi_max_timeout = 300
cmd = 'timeout {} nvidia-smi'+\
      ' --query-gpu=utilization.gpu,utilization.memory'+\
      ' --format=csv,nounits -lms 100 -f GPU-info.csv'
cmd = cmd.format(nvidia_smi_max_timeout)
print("Running process: [{}]".format(cmd))
nvidia_smi = subprocess.Popen(shlex.split(cmd))
# ----------

# ===== EVERYTHING ABOVE HERE IS IDENTICAL BETWEEN "Plain feed_dict" and "with Queues".

import threading

tf_queue_capacity = 50
number_of_enqueuer_threads = 2

# Define Tensorflow Queue
q = tf.FIFOQueue(capacity=tf_queue_capacity, dtypes=[tf.float32, tf.float32])
# .. and two tensors which are gotten by dequeuing.
q_inputs, q_labels = q.dequeue()

# :: Define inputs, labels, and Neural Network..

# Input values - NOTICE use of "placeholder_with_default(...)" here, to feed from queue
inputs = tf.placeholder_with_default(q_inputs, [None, 28*28])
# Labels - "factual" - about the current input - also defaulting to feed from queue
labels = tf.placeholder_with_default(q_labels, [None, 10])

# Set up the Network with the input and labels, 
# (.. which can now be feed both from feed_dict and the queue)
train, cost, accuracy = createNeuralNet(inputs, labels)

### Train Neural Network

# Strange way to enqueue.. Use tf.placeholder, then get "op" for the enqueuing
batch_inputs_ph = tf.placeholder(tf.float32)
batch_labels_ph = tf.placeholder(tf.float32)
enqueue_op = q.enqueue([batch_inputs_ph, batch_labels_ph])

# Initialize TensorFlow variables in Session
s.run(tf.global_variables_initializer())
# .. ensure that we don't mess more with the graph anymore after this..
tf.get_default_graph().finalize()

# The enqueuer "lambda", run by the enqueuer threads
def training_enqueuer(thread_idx, sess, coord):
    print("Thread {} loading local MNIST data".format(thread_idx))
    mnist_local = input_data.read_data_sets("tmp", seed=thread_idx, 
                                            one_hot=True, validation_size=0)
    # mnist_local = mnist
    i = 1
    while not coord.should_stop():
        if (i % 500 == 0):
            print("Enqueuer thread {} at mini batch generation {}".format(thread_idx, i))
        i += 1
        # Fetch batch inputs and labels, put them on the queue
        batch_inputs, batch_labels = mnist_local.train.next_batch(mini_batch_size)
        sess.run(enqueue_op, feed_dict={batch_inputs_ph: batch_inputs, 
                                        batch_labels_ph: batch_labels})
        # if fuckup :
        #    coord.request_stop()
    print("Enqueuer thread {} stopped!".format(thread_idx))

# Main thread: create a coordinator.
coord = tf.train.Coordinator()

# Create X threads that run 'training_enqueuer()'
threads = [threading.Thread(target=training_enqueuer, 
                            args=(thread_idx, s, coord)) \
           for thread_idx in range(number_of_enqueuer_threads)]

# Start the enqueuer threads
for t in threads:
    t.start()

printStats("BEFORE Training")

### Train Neural Network

# Run training
time_start = timer()
for mini_batch in range(1, total_mini_batches+1):
    s.run([train, accuracy])
    if (mini_batch % mini_batches_per_epoch == 0):
        printStats("After mini batch {} of {}".format(mini_batch, total_mini_batches))
    if (mini_batch == total_mini_batches - tf_queue_capacity + 10):
        print("Close to total_mini_batches: {}/{} - requesting enqueuer threads to stop."\
             .format(mini_batch, total_mini_batches))
        coord.request_stop()
        print("Requested Threads to stop via Coordinator.")
        
training_time = timer()-time_start

print("Joining all Threads")
coord.join(threads)
print("Joined all Threads")

# ----------
import time
time.sleep(0.5)
nvidia_smi.terminate()
time.sleep(0.5)

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
sb.set_style("darkgrid")
gpu = pd.read_csv("./GPU-info.csv")
gpu.plot()
plt.show()
# ----------

printStats("\nFINISHED")
print("TRAINING took {} seconds.".format(training_time))
# Out:
# Extracting tmp/train-images-idx3-ubyte.gz
# Extracting tmp/train-labels-idx1-ubyte.gz
# Extracting tmp/t10k-images-idx3-ubyte.gz
# Extracting tmp/t10k-labels-idx1-ubyte.gz
#
# Neural network: Hidden1:800, Hidden2:800
#  Training size:60000 * epochs:20 / mini_batch_size:128 = total_mini_batches:9360
#  Learning rate:0.0001
#
# Running process: [timeout 300 nvidia-smi --query-gpu=utilization.gpu,utilization.memory --format=csv,nounits -lms 100 -f GPU-info.csv]
# Thread 0 loading local MNIST data
# Thread 1 loading local MNIST data
# Extracting Extracting tmp/train-images-idx3-ubyte.gz
# tmp/train-images-idx3-ubyte.gz
# BEFORE Training
#   TRAIN cost/acc:4.7548/0.1244, TEST cost/acc:4.8266/0.1218
# Extracting tmp/train-labels-idx1-ubyte.gz
# Extracting tmp/train-labels-idx1-ubyte.gz
# Extracting tmp/t10k-images-idx3-ubyte.gz
# Extracting tmp/t10k-images-idx3-ubyte.gz
# Extracting tmp/t10k-labels-idx1-ubyte.gz
# Extracting tmp/t10k-labels-idx1-ubyte.gz
# After mini batch 468 of 9360
#   TRAIN cost/acc:0.2110/0.9392, TEST cost/acc:0.2170/0.9355
# After mini batch 936 of 9360
#   TRAIN cost/acc:0.1480/0.9575, TEST cost/acc:0.1640/0.9494
# Enqueuer thread 1 at mini batch generation 500
# Enqueuer thread 0 at mini batch generation 500
# After mini batch 1404 of 9360
#   TRAIN cost/acc:0.1046/0.9704, TEST cost/acc:0.1279/0.9603
# After mini batch 1872 of 9360
#   TRAIN cost/acc:0.0859/0.9759, TEST cost/acc:0.1196/0.9648
# Enqueuer thread 1 at mini batch generation 1000
# Enqueuer thread 0 at mini batch generation 1000
# After mini batch 2340 of 9360
#   TRAIN cost/acc:0.0678/0.9819, TEST cost/acc:0.1049/0.9669
# After mini batch 2808 of 9360
#   TRAIN cost/acc:0.0562/0.9848, TEST cost/acc:0.0920/0.9727
# Enqueuer thread 1 at mini batch generation 1500
# Enqueuer thread 0 at mini batch generation 1500
# After mini batch 3276 of 9360
#   TRAIN cost/acc:0.0517/0.9860, TEST cost/acc:0.0948/0.9705
# After mini batch 3744 of 9360
#   TRAIN cost/acc:0.0353/0.9913, TEST cost/acc:0.0778/0.9765
# Enqueuer thread 1 at mini batch generation 2000
# Enqueuer thread 0 at mini batch generation 2000
# After mini batch 4212 of 9360
#   TRAIN cost/acc:0.0315/0.9930, TEST cost/acc:0.0806/0.9763
# After mini batch 4680 of 9360
#   TRAIN cost/acc:0.0253/0.9946, TEST cost/acc:0.0744/0.9777
# Enqueuer thread 1 at mini batch generation 2500
# Enqueuer thread 0 at mini batch generation 2500
# After mini batch 5148 of 9360
#   TRAIN cost/acc:0.0233/0.9949, TEST cost/acc:0.0768/0.9772
# After mini batch 5616 of 9360
#   TRAIN cost/acc:0.0178/0.9969, TEST cost/acc:0.0726/0.9767
# Enqueuer thread 1 at mini batch generation 3000
# Enqueuer thread 0 at mini batch generation 3000
# After mini batch 6084 of 9360
#   TRAIN cost/acc:0.0144/0.9978, TEST cost/acc:0.0688/0.9784
# After mini batch 6552 of 9360
#   TRAIN cost/acc:0.0129/0.9982, TEST cost/acc:0.0709/0.9789
# Enqueuer thread 1 at mini batch generation 3500
# Enqueuer thread 0 at mini batch generation 3500
# After mini batch 7020 of 9360
#   TRAIN cost/acc:0.0132/0.9976, TEST cost/acc:0.0752/0.9785
# After mini batch 7488 of 9360
#   TRAIN cost/acc:0.0086/0.9990, TEST cost/acc:0.0686/0.9781
# Enqueuer thread 1 at mini batch generation 4000
# After mini batch 7956 of 9360
#   TRAIN cost/acc:0.0089/0.9985, TEST cost/acc:0.0720/0.9791
# Enqueuer thread 0 at mini batch generation 4000
# After mini batch 8424 of 9360
#   TRAIN cost/acc:0.0071/0.9991, TEST cost/acc:0.0689/0.9790
# After mini batch 8892 of 9360
#   TRAIN cost/acc:0.0061/0.9993, TEST cost/acc:0.0694/0.9799
# Enqueuer thread 1 at mini batch generation 4500
# Enqueuer thread 0 at mini batch generation 4500
# Close to total_mini_batches: 9320/9360 - requesting enqueuer threads to stop.
# Requested Threads to stop via Coordinator.
# Enqueuer thread 0 stopped!
# Enqueuer thread 1 stopped!
# After mini batch 9360 of 9360
#   TRAIN cost/acc:0.0049/0.9996, TEST cost/acc:0.0695/0.9793
# Joining all Threads
# Joined all Threads
# FINISHED
#   TRAIN cost/acc:0.0049/0.9996, TEST cost/acc:0.0695/0.9793
# TRAINING took 15.41126602794975 seconds.
